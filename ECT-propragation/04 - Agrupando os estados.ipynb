# %% [markdown]
# # Agrupandos dos diferentes estados dos alunos de C&T
# ## objetivo
# O objetivo desse notebook é lista todos os estados possíveis de um aluno em C&T, tendo como vista
# as materias que ele pode pagar nesse curso. Serão listadas apenas as disciplinas oferecidas pelo departamento,
# tendo em vista que o objetivo é listar os primeiros semestres, onde ainda não há uma necessidade tão
# grande de pagar matérias em outros departamentos.

# %% [markdown]
# ## Definição de Estado
# Um Estado é formado pelo conjunto de disciplinas que o discente está pagando naquele semestre, assim, haverá um
# estado para cada possibilidade possível de disciplinas. Os estados com menor adesão serão tidos como outlies e
# não serão utilizados na aplicação do algoritmo.

# %%
import pandas as pd
import numpy as np

# %%
matr = pd.read_csv("data/outputs/matr_final_20172.csv", sep=";")

# %%
matr.head()
# Out:
#    id_turma                          discente    id_curso  media_final  \
# 0  57603646  c119d334d6c55121d48dc7f5d43bbe1f  10320810.0          8.2
# 1  57603630  30156bac31160066c22688ccc9fa1287  10320810.0          1.0
# 2  57603630  7c8756bfafd6623effbeefe83ac2ea15  10320810.0          7.0
# 3  57603833  972c641f5303e93483e5c318ef19e0cd  10320810.0          7.3
# 4  57606520  e0830e6363b8c6a692d3aea55eab73c1  10320810.0          5.0
#
#    numero_total_faltas                         descricao  \
# 0                  4.0                          APROVADO
# 1                 48.0  REPROVADO POR MÉDIA E POR FALTAS
# 2                  4.0                          APROVADO
# 3                  0.0                          APROVADO
# 4                  0.0                 APROVADO POR NOTA
#
#    id_componente_curricular   ano  periodo   codigo  \
# 0                     25009  2017        2  DEF0152
# 1                     25025  2017        2  DEF0054
# 2                     25025  2017        2  DEF0054
# 3                     25042  2017        2  DEF0051
# 4                     25455  2017        2  ELE0500
#
#                                nome curso_componente
# 0                   CULTURA POPULAR              NaN
# 1          METODOLOGIA DO ATLETISMO              NaN
# 2          METODOLOGIA DO ATLETISMO              NaN
# 3             METODOLOGIA DO FUTSAL              NaN
# 4  INTRODUCAO A ENGENHARIA ELETRICA              NaN

# %% [markdown]
# ## Agrupando por Discentes
# Nesse passo, vamos agrupar as matriculas por discentes a fim de começar a mapear os estados e
# verificar possíveis outliers.

# %%
# matr.groupby('discente')['discente'].count().sort_values(ascending=False)

# %%
matr.descricao.unique()
# Out:
# array(['REPROVADO POR MÉDIA E POR FALTAS', 'APROVADO POR NOTA',
#        'APROVADO', 'TRANCADO', 'REPROVADO', 'REPROVADO POR NOTA',
#        'REPROVADO POR FALTAS', 'REPROVADO POR NOTA E FALTA'], dtype=object)

# %%
matr.sort_values('codigo', ascending=True, inplace=True)

# %%
matr['descricao'] = matr['descricao'].map({'REPROVADO POR MÉDIA E POR FALTAS': 'R', 'REPROVADO POR NOTA': 'R',
                 'REPROVADO POR NOTA E FALTA': 'R',
                 'REPROVADO POR FALTAS': 'R', 'REPROVADO': 'R',
                'APROVADO POR NOTA': 'A', 'APROVADO': 'A', 'TRANCADO': 'T'})

# %%
group = matr[['discente', 'codigo', 'descricao']].groupby('discente')

# %%
group.agg(lambda x: ','.join(x))
# Out:
#                                                                           descricao
# discente
# 0010345ff1be7da25478b5a96c772616  REPROVADO,APROVADO POR NOTA,APROVADO POR NOTA,...
# 005cdf6ddf92e14dfa387c87f3f6e946  APROVADO POR NOTA,APROVADO POR NOTA,APROVADO,A...
# 00a54c3ed49fdd50c7dd248458255e17  APROVADO POR NOTA,REPROVADO,REPROVADO,APROVADO...
# 00b4c9b8bd631422f6a05bad05774d2b  TRANCADO,APROVADO POR NOTA,REPROVADO,TRANCADO,...
# 00c95b0e427b18e5443272c0c01549c3  REPROVADO POR MÉDIA E POR FALTAS,REPROVADO POR...
# 00d67b98ad2471688f50b37e26017c8e  REPROVADO,REPROVADO,REPROVADO,APROVADO POR NOT...
# 011a9ba9e3300b9774c2422832e2e775  APROVADO,APROVADO,APROVADO POR NOTA,REPROVADO,...
# 0120b6290275041d959e36cc17bbf368  REPROVADO,REPROVADO POR MÉDIA E POR FALTAS,APR...
# 014d0049a66c06dd7b4b97d25b5530c3  APROVADO POR NOTA,APROVADO POR NOTA,APROVADO P...
# 015eb3a978d70ee070a21cb5f518ae39  APROVADO POR NOTA,APROVADO POR NOTA,APROVADO P...
# 0160ae592647ea9fa87a8a3061ce0dae  REPROVADO POR MÉDIA E POR FALTAS,REPROVADO POR...
# 016bbd710b1768cbb76bfa9e329d92a5  APROVADO POR NOTA,APROVADO POR NOTA,APROVADO,A...
# 016e08499aa227b0ee97167dcb41a8d9  APROVADO POR NOTA,APROVADO POR NOTA,APROVADO P...
# 017a8072747270d3291356eb8ebf59a5  APROVADO,APROVADO POR NOTA,APROVADO POR NOTA,A...
# 019029acd79434f52027fae69f97ac01  APROVADO,APROVADO,APROVADO,APROVADO POR NOTA,A...
# 01a1a27f64f5ed4069168bf2a437f06d              REPROVADO,REPROVADO,APROVADO POR NOTA
# 01bcec86f5d397b7c999465e642b80bc  APROVADO POR NOTA,REPROVADO POR MÉDIA E POR FA...
# 01f801943d53b7bc108b20043cfb38a0  REPROVADO,REPROVADO,REPROVADO,APROVADO POR NOT...
# 01fe19e895e1da46dad444e896932632  APROVADO,REPROVADO,APROVADO POR NOTA,APROVADO,...
# 0200f9a5a580fafbce1668df030da956                                  APROVADO,APROVADO
# 02209f809703ce8fd6cde21455f66f00  APROVADO POR NOTA,REPROVADO,APROVADO POR NOTA,...
# 0229591e3b5d8d118ca945794774159a                        APROVADO POR NOTA,REPROVADO
# 023a619aa389f8235052747055b69cfd  TRANCADO,TRANCADO,TRANCADO,APROVADO POR NOTA,A...
# 024a2eaa2b3cff0837a44bfa7350a0cc  REPROVADO,REPROVADO,REPROVADO POR MÉDIA E POR ...
# 026d255595d23988a3710bfd69c4e1aa  APROVADO POR NOTA,APROVADO POR NOTA,REPROVADO,...
# ff7f51a2ae164d106ef666ff2c277b1e  APROVADO,APROVADO POR NOTA,REPROVADO,APROVADO,...
# ff8f066c70395983aff3f1d311da4683  APROVADO POR NOTA,APROVADO POR NOTA,REPROVADO,...
# ffa3e83772fa2383771befb56a21fa7b  APROVADO,APROVADO,REPROVADO POR MÉDIA E POR FA...
# ffb707525f2081fbec30a0ef15bbc4fa          APROVADO,REPROVADO POR MÉDIA E POR FALTAS
# ffb7b904ab4eec741ee423353f363b27       APROVADO,APROVADO,APROVADO,APROVADO POR NOTA
# ffbc418dec6ab536164464f7b8195c59  REPROVADO,REPROVADO,REPROVADO,REPROVADO POR MÉ...
# ffeafa5170c693e31a4e8da4cae42313  APROVADO POR NOTA,APROVADO POR NOTA,REPROVADO,...
# fff42796a17f503b99e173928c46aab2  APROVADO POR NOTA,APROVADO POR NOTA,APROVADO P...
# fff8c402febf8217f10b5c1e57dfb522  REPROVADO,APROVADO POR NOTA,APROVADO POR NOTA,...
#
# [2847 rows x 1 columns]

# %% [markdown]
# ## Criando os Estados
# Nesse passo, vamos criar os estados dos discentes, sendo verificado as disciplinas que estão sendo pagas e
# perando um hash para cada conjunto de disciplinas.
#
# Pode ser criado um discionários ou estrutura semelhante para armazenar os hashs que serão criados e agrupados.

# %%
hash(str(['ECT2414', 'ECT0123', 'ECT1241']))
# Out:
# 7125945113005725043

# %%
def hash_situacao(descricao):
    '''
    Função para computar o resultado do discente no semestre.
    '''
    situacoes = list(descricao)
    situacoes.replace

# %%
def hash_disciplinas(disciplinas):
    '''
    Função que calcula um hash para as disciplinas. Assim será possível varer todos os estados possíveis.
    
    A função recebe uma lista de disciplinas e retorna um valor hash.
    >>> hash_disciplinas(['ECT2414', 'ECT0123', 'ECT1241'])
    '3-2914823815191669391'
    '''
    # O primeiro numero é a quantidade de disciplinas
    hash_ = str(len(disciplinas))
    
    # Ordena o vetor de disciplinas e gera uma string dele
    disc = list(disciplinas)
    disc.sort()
    hash_ += "".join(disc)
    
    return hash_

# %%
hash_disciplinas(['ECT2414', 'ECT0123', 'ECT1241'])
# Out:
# '3ECT0123ECT1241ECT2414'

# %% [markdown]
# ## Agrupando os discentes por Estado

# %%
# Aplicando a função hash_disciplinas no nosso grupo

estados = group.agg(hash_disciplinas)
type(estados)
# Out:
# pandas.core.frame.DataFrame

# %%
estados.groupby('codigo')['codigo'].count().sort_values(ascending=False)
# Out:
# codigo
# 6ECT2101ECT2102ECT2103ECT2104ECT2105ECT2106                                 469
# 7ECT2201ECT2202ECT2203ECT2204ECT2205ECT2206ECT2207                           56
# 7ECT2301ECT2302ECT2303ECT2304ECT2305ECT2306ECT2307                           15
# 6ECT2401ECT2402ECT2403ECT2411ECT2412ECT2413                                  13
# 6ECT2201ECT2202ECT2203ECT2204ECT2205ECT2302                                  10
# 6ECT2103ECT2202ECT2203ECT2205ECT2206ECT2306                                   9
# 6DEB0504ECT2201ECT2202ECT2203ECT2304ECT2307                                   1
# 6DEB0504ECT2201ECT2206ECT2304ECT2307ECT2411                                   1
# 6DEB0504ECT2202ECT2301ECT2304ECT2402ECT2416                                   1
# 6DEB0504ECT2402ECT2403ECT2411ECT2413ECT2416                                   1
# 6DEB0505DEB0706ECT2303ECT2306ECT2411ECT2413                                   1
# 6DEB0601ECT2201ECT2202ECT2204ECT2303ICE1038                                   1
# 6DEB0602DEB0603DEB0706DFS0028ECT2413ECT2414                                   1
# 6DEB0602DEB0603DEB1108ECT2413ECT2701ICE1022                                   1
# 6DEB0602DEB0706DFS0028ECT2301ECT2411ECT2413                                   1
# 6DEB0602ECT2103ECT2104ECT2203ECT2205ECT2302                                   1
# 6DEB0706ECT2104ECT2303ECT2304ECT2402ECT2403                                   1
# 6DEF0038ECT1553ECT2303ECT2304ECT2307ECT2307                                   1
# 10CIV1101CIV1104CIV1106CIV1205DEF0650ECT1530ECT1560ECT2302MTR0302MTR0354      1
# Name: codigo, Length: 1977, dtype: int64

# %% [markdown]
# ## Analisando só materias obrigatórias

# %%
obrig_s1 = ['ECT2101', 'ECT2102', 'ECT2103', 'ECT2104', 'ECT2105', 'ECT2106']
obrig_s2 = ['ECT2201', 'ECT2202', 'ECT2203', 'ECT2204', 'ECT2205', 'ECT2206', 'ECT2207']
obrig_s3 = ['ECT2301', 'ECT2302', 'ECT2303', 'ECT2304', 'ECT2305', 'ECT2306', 'ECT2307']
obrig_s4 = ['ECT2401', 'ECT2402', 'ECT2403', 'ECT2311', 'ECT2412', 'ECT2413', 'ECT2414']

obrig = obrig_s1 + obrig_s2 + obrig_s3 + obrig_s4

# %%
# Pegando apenas as matriculas em disciplinas obrigadorias
matr_obrig = matr[matr.codigo.isin(obrig)]
group_ob = matr_obrig[['discente', 'codigo']].groupby('discente')

estados_ob = group_ob.agg(hash_disciplinas)

# %%
estados_ob.groupby('codigo')['codigo'].count().sort_values(ascending=False)
# Out:
# codigo
# 6ECT2101ECT2102ECT2103ECT2104ECT2105ECT2106                  472
# 1ECT2414                                                     105
# 7ECT2201ECT2202ECT2203ECT2204ECT2205ECT2206ECT2207            60
# 5ECT2401ECT2402ECT2403ECT2412ECT2413                          41
# 1ECT2302                                                      36
# 1ECT2401                                                      31
# 1ECT2206                                                      26
# 1ECT2413                                                      25
# 2ECT2413ECT2414                                               20
# 7ECT2301ECT2302ECT2303ECT2304ECT2305ECT2306ECT2307            20
# 3ECT2402ECT2403ECT2413                                        19
# 2ECT2206ECT2302                                               17
# 4ECT2401ECT2402ECT2403ECT2412                                 16
# 2ECT2412ECT2414                                               15
# 3ECT2412ECT2413ECT2414                                        14
# 4ECT2402ECT2403ECT2412ECT2413                                 13
# 1ECT2412                                                      12
# 4ECT2401ECT2402ECT2403ECT2413                                 11
# 6ECT2201ECT2202ECT2203ECT2204ECT2205ECT2302                   10
# 00d67b98ad2471688f50b37e26017c8e       20172
# 011a9ba9e3300b9774c2422832e2e775       20172
# 0120b6290275041d959e36cc17bbf368       20172
# 014d0049a66c06dd7b4b97d25b5530c3       20172
# 015eb3a978d70ee070a21cb5f518ae39       20172
# 0160ae592647ea9fa87a8a3061ce0dae       20172
# 016bbd710b1768cbb76bfa9e329d92a5       20172
# 016e08499aa227b0ee97167dcb41a8d9       20172
# 017a8072747270d3291356eb8ebf59a5       20172
# 019029acd79434f52027fae69f97ac01       20172
# 01a1a27f64f5ed4069168bf2a437f06d       20172
# 01f801943d53b7bc108b20043cfb38a0       20172
# 01fe19e895e1da46dad444e896932632       20172
# 02209f809703ce8fd6cde21455f66f00       20172
# 0229591e3b5d8d118ca945794774159a       20172
# 023a619aa389f8235052747055b69cfd       20172
# 024a2eaa2b3cff0837a44bfa7350a0cc       20172
# 026d255595d23988a3710bfd69c4e1aa       20172
# 026da54005e7bfedee979619068acadf       20172
# 02a5d5602dae1b618335d470f804dd37       20172
# 02f1e0f37d8745d06da09219e4eca2ba       20172
# 03055d34de34cca0dd895e36c7125fb7       20172
# 034b7fed49bd43462e957a16ab60302d       20172
# 034b98ad643d6b9e505ec8d1caba17da       20172
# 0376f7de3dc77e615a2faaad02b13431       20172
# ...                                      ...
# fdbc55a46a0f83faba352912e61ca710       20172
# fe0e1d7f2e679df00d2e7140bf9bfa9c       20172
# fe1b61601a61e86a9da4110ee31091be       20172
# fe4aa453d1ae64b42250437f38559999       20172
# fe543b1d679707f728a236cb875c7c61       20172
# fe588b66fb1e78511b46aa9a85ddcd3f       20172
# fe759c27a4bc70f6b09b2991448deaf1       20172
# fe7a95c91b1904ac826f2c7f225cb8f4       20172
# fe8fa6a1655491522dd2d70059a91a6a       20172
# fe987f2702dc8b51d754e8915f73b5fc       20172
# feab271fbf2a45b36da00477a8bc095e       20172
# feb6501fa6bad977bd1b62cbd3df7fec       20172
# feba3948d9b72a69a4df24e58775af48       20172
# fed232855bd36da8686d2771a6b73ab7       20172
# fed8da2d9ec9bf4d505a3a391cd015cf       20172
# feff038a163b36ff9409c6dfca555f92       20172
# ff0c6b7b3c18fbab86089dace2b5675b       20172
# ff0ea124253b434c9b32b4a9cfa688ef       20172
# ff1e29f8ec9277e81fba89eee4260118       20172
# ff1ef23ede009879643cff0470e0ebc4       20172
# ff3aa6e5cbcc4e8f9f2bbfe3a207eb26       20172
# ff5b0347c5068c1b35c680eb72a39fd8       20172
# ff6bb0b6cb632b75f87e84f3b66d2947       20172
# ff7f51a2ae164d106ef666ff2c277b1e       20172
# ffb707525f2081fbec30a0ef15bbc4fa       20172
# ffb7b904ab4eec741ee423353f363b27       20172
# ffbc418dec6ab536164464f7b8195c59       20172
# ffeafa5170c693e31a4e8da4cae42313       20172
# fff42796a17f503b99e173928c46aab2       20172
# fff8c402febf8217f10b5c1e57dfb522       20172
#
# [2539 rows x 2 columns]
