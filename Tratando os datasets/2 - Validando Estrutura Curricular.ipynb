# %%
import pandas as pd
import numpy as np

# %%
disciplinas = pd.read_csv("./data/componentes-curriculares-presenciais-ok.csv")
disciplinas.shape
# Out:
# (36079, 30)

# %%
departamentos_selecionados = ['ESCOLA DE CIÊNCIAS E TECNOLOGIA', 'INSTITUTO METROPOLE DIGITAL',
                             'DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUTOMACAO']
disc_sel = disciplinas[disciplinas.unidade_responsavel.isin(departamentos_selecionados)]

# %%
disc = disc_sel[['id_componente', 'codigo','nome','unidade_responsavel']]
disc.head()
# Out:
#      id_componente   codigo                                           nome  \
# 192          20005  DCA0451                            COMPUTACAO NUMERICA
# 193          20006  DCA0416   SISTEMAS ESPECIALISTAS APLICADOS A AUTOMACAO
# 199          20012  DCA0404                    ARQUITETURA DE COMPUTADORES
# 200          20013  DCA0418  SUPERVISAO E CONTROLE OPERACIONAL DE SISTEMAS
# 201          20014  DCA0443             CONTROLADORES LOGICOS PROGRAMAVEIS
#
#                                    unidade_responsavel
# 192  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 193  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 199  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 200  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 201  DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...

# %%
cursos = pd.read_csv("./data/cursos-de-graduacao.csv", sep=";")
estr_curric = pd.read_csv("./data/estruturas-curriculares.csv", sep=";")
curric_comp = pd.read_csv("./data/curriculo-componente-graduacao.csv", sep=";")

# %%
dict_cursos =  {'CET' : 'CIÊNCIAS E TECNOLOGIA','BTI' : 'TECNOLOGIA DA INFORMAÇÃO','ENGCOMP' : 'ENGENHARIA DE COMPUTAÇÃO'}
cursos_selecionados = cursos[cursos.nome.isin(dict_cursos.values())]
cursos_selecionados[['nome','id_curso']]
# Out:
#                          nome  id_curso
# 15      CIÊNCIAS E TECNOLOGIA  10320810
# 38   ENGENHARIA DE COMPUTAÇÃO   2000026
# 111  TECNOLOGIA DA INFORMAÇÃO  92127264

# %%
# Estrutura curricular de engComp e BTI já estão as atuais de 2012 e 2014, respectivamente# estr_bti = estr_curric_sel[estr_curric_sel.nome_curso.isin([dict_cursos['BTI']])]
# estr_eng_comp = estr_curric_sel[estr_curric_sel.nome_curso.isin([dict_cursos['ENGCOMP']])]
# estr_curric_sel.loc[(estr_curric_sel.nome_curso.isin(dict_cursos.values())) & (estr_curric_sel.nome_curso.isin([dict_cursos['CET']]) & (estr_curric_sel.ano_entrada_vigor >= 2016)),['id_curriculo','nome_curso']]
estr_curric_sel = estr_curric[estr_curric.id_curso.isin(cursos_selecionados.id_curso.unique())]
estr_bct = estr_curric_sel.loc[estr_curric_sel.nome_curso.isin([dict_cursos['CET']]) & (estr_curric_sel.ano_entrada_vigor < 2016)].id_curriculo
estr_curric_sel = estr_curric_sel[~estr_curric_sel.id_curriculo.isin(estr_bct)]

# %%
estr_curric_sel[['id_curriculo','nome_matriz' ,'ano_entrada_vigor']]
# Out:
#      id_curriculo                                        nome_matriz  \
# 21      101658777  TECNOLOGIA DA INFORMAÇÃO - NATAL - MT - BACHAR...
# 22      101669382  TECNOLOGIA DA INFORMAÇÃO - NATAL - N - BACHARE...
# 44      101659860  TECNOLOGIA DA INFORMAÇÃO - NATAL - N - BACHARE...
# 47      101668583  TECNOLOGIA DA INFORMAÇÃO - NATAL - MT - BACHAR...
# 115     105755388  TECNOLOGIA DA INFORMAÇÃO - NATAL - MT - BACHAR...
# 136     115765126   CIÊNCIAS E TECNOLOGIA - NATAL - MT - BACHARELADO
# 234     102200805  TECNOLOGIA DA INFORMAÇÃO - NATAL - MT - BACHAR...
# 244     115305512   CIÊNCIAS E TECNOLOGIA - NATAL - MT - BACHARELADO
# 254      89059693   ENGENHARIA DE COMPUTAÇÃO - NATAL - MT - FORMAÇÃO
# 264     115306301    CIÊNCIAS E TECNOLOGIA - NATAL - N - BACHARELADO
# 273     115307035    CIÊNCIAS E TECNOLOGIA - NATAL - N - BACHARELADO
# 275     115803290  CIÊNCIAS E TECNOLOGIA - NATAL - MTN - BACHARELADO
# 276     115272412    CIÊNCIAS E TECNOLOGIA - NATAL - N - BACHARELADO
# 277     115273212    CIÊNCIAS E TECNOLOGIA - NATAL - T - BACHARELADO
# 289     115306807   CIÊNCIAS E TECNOLOGIA - NATAL - MT - BACHARELADO
# 299     115764587    CIÊNCIAS E TECNOLOGIA - NATAL - N - BACHARELADO
# 310     115802434   CIÊNCIAS E TECNOLOGIA - NATAL - MT - BACHARELADO
# 330     101669220  TECNOLOGIA DA INFORMAÇÃO - NATAL - N - BACHARE...
#
#      ano_entrada_vigor
# 21                2014
# 22                2014
# 44                2014
# 47                2014
# 115               2014
# 136               2016
# 234               2014
# 244               2016
# 254               2012
# 264               2016
# 273               2016
# 275               2016
# 276               2016
# 277               2016
# 289               2016
# 299               2016
# 310               2016
# 330               2014

# %%
curric_comp[curric_comp.id_componente_curricular.isin(estr_curric_sel.id_curriculo)]
# Out:
# Empty DataFrame
# Columns: [id_curriculo_componente, id_curriculo, id_componente_curricular, semestre_oferta, tipo_vinculo_componente, nivel_ensino]
# Index: []

# %%
disc.to_csv("./outputs/disciplinas-selecionadas.csv", encoding='UTF-8', )

# %%
disc
# Out:
#        id_componente   codigo  \
# 192            20005  DCA0451
# 193            20006  DCA0416
# 199            20012  DCA0404
# 200            20013  DCA0418
# 201            20014  DCA0443
# 202            20015  DCA0420
# 216            20029  DCA0414
# 217            20030  DCA0441
# 218            20031  DCA0440
# 219            20032  DCA0435
# 221            20034  DCA0304
# 1222           21072  DCA0450
# 1224           21074  DCA0448
# 1225           21075  DCA0446
# 1226           21076  DCA0454
# 1227           21077  DCA0431
# 1228           21078  DCA0436
# 1229           21079  DCA0452
# 1231           21081  DCA0447
# 1232           21082  DCA0449
# 1234           21084  DCA0445
# 1235           21085  DCA0802
# 1236           21086  DCA0453
# 1238           21088  DCA0803
# 1860           21718  DCA0900
# 1861           21719  DCA0432
# 1873           21731  DCA0405
# 1877           21735  DCA0406
# 2478           22365  DCA0372
# 2502           22389  DCA0407
# ...              ...      ...
# 35091        2051704  ECT1303
# 35092        2051705  ECT1304
# 35093        2051706  ECT1305
# 35094        2051707  ECT1306
# 35095        2051708  ECT1307
# 35096        2051709  ECT1530
# 35097        2051710  ECT1531
# 35098        2051711  ECT1532
# 35099        2051712  ECT1401
# 35100        2051713  ECT1510
# 35101        2051714  ECT1511
# 35102        2051715  ECT1512
# 35103        2051750  ECT1540
# 35104        2051751  ECT1541
# 35105        2051752  ECT1542
# 35106        2051753  ECT1543
# 35107        2051754  ECT1544
# 35108        2051755  ECT1545
# 35109        2051756  ECT1546
# 35110        2051757  ECT1547
# 35111        2051758  ECT1500
# 35112        2051759  ECT1502
# 35113        2051760  ECT1520
# 35114        2051761  ECT1521
# 35115        2051762  ECT1522
# 35117        2051850  ECT1501
# 35118        2051851  ECT1550
# 35119        2051852  ECT1560
# 35120        2051853  ECT1561
# 35189        2052000  ECT1901
#
#                                                     nome  \
# 192                                  COMPUTACAO NUMERICA
# 193         SISTEMAS ESPECIALISTAS APLICADOS A AUTOMACAO
# 199                          ARQUITETURA DE COMPUTADORES
# 200        SUPERVISAO E CONTROLE OPERACIONAL DE SISTEMAS
# 201                   CONTROLADORES LOGICOS PROGRAMAVEIS
# 202                   LINGUAGEM DE DESCRICAO DE HARDWARE
# 216                                INTRODUCAO A ROBOTICA
# 217                        TOPICOS ESPECIAIS EM ROBOTICA
# 218                         SISTEMAS ROBOTICOS AUTONOMOS
# 219                                   COMPUTACAO GRAFICA
# 221                 METODOS COMPUTACIONAIS EM ENGENHARIA
# 1222                               REDES DE COMPUTADORES
# 1224                   SISTEMAS PARALELOS E DISTRIBUIDOS
# 1225    TOPICOS ESPECIAIS EM PROCESSAMENTO DA INFORMACAO
# 1226                           REDES NEURAIS ARTIFICIAIS
# 1227                                 TEORIA DE CIRCUITOS
# 1228                                SISTEMAS DE CONTROLE
# 1229                                    CONTROLE DIGITAL
# 1231                     REDES PARA AUTOMACAO INDUSTRIAL
# 1232          TOPICOS ESPECIAIS EM REDES DE COMPUTADORES
# 1234                    PROCESSAMENTO DIGITAL DE IMAGENS
# 1235   TOPICOS ESPECIAIS EM METODOS NUMERICOS PARA EN...
# 1236                     PROCESSAMENTO DIGITAL DE SINAIS
# 1238                                PROGRAMACAO AVANCADA
# 1860                    INTELIGENCIA ARTIFICIAL APLICADA
# 1861                    INTELIGENCIA ARTIFICIAL APLICADA
# 1873            MODELOS ORIENTADOS A OBJETO EM AUTOMACAO
# 1877                            REDES DE COMPUTADORES II
# 2478                             INTELIGENCIA ARTIFICIAL
# 2502            INSTRUMENTACAO PARA CONTROLE E AUTOMACAO
# ...                                                  ...
# 35091                                COMPUTAÇÃO NUMÉRICA
# 35092     PRINCÍPIOS E FENÔMENOS TÉRMICOS E ONDULATÓRIOS
# 35093            PRINCÍPIOS E FENÔMENOS ELETROMAGNÉTICOS
# 35094                CIÊNCIA, TECNOLOGIA E SOCIEDADE III
# 35095            PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS
# 35096  PRÁTICAS DE LEITURA E ESCRITA DE GÊNEROS ACADÊ...
# 35097  PRÁTICAS DE LEITURA E ESCRITA DE GÊNEROS DA ES...
# 35098  PRÁTICA DE LEITURA E ESCRITA DE GÊNEROS ACADÊM...
# 35099                 CIÊNCIA E TECNOLOGIA DOS MATERIAIS
# 35100          NOVAS FRONTEIRAS EM CIÊNCIAS E TECNOLOGIA
# 35101      FUNDAMENTOS E APLICAÇÕES DA MECÂNICA QUÂNTICA
# 35102                          CIÊNCIAS E INSTRUMENTAÇÃO
# 35103                    PROGRAMAÇÃO ORIENTADA A OBJETOS
# 35104                                 ESTRUTURA DE DADOS
# 35105                              SISTEMAS DISTRIBUIDOS
# 35106                                     BANCO DE DADOS
# 35107                             ENGENHARIA DE SOFTWARE
# 35108                            ARQUITETURA DE SOFTWARE
# 35109                              QUALIDADE DE SOFTWARE
# 35110                   TÓPICOS AVANÇADOS EM INFORMÁTICA
# 35111                               MÉTODOS ESTATÍSTICOS
# 35112                INTRODUÇÃO À INFERÊNCIA ESTATÍSTICA
# 35113                                 SISTEMAS DINÂMICOS
# 35114               RACIOCÍNIO LÓGICO E TEORIA DOS JOGOS
# 35115  FUNDAMENTOS MATEMÁTICOS DA CRIPTOGRAFIA E TEOR...
# 35117    HISTÓRIA E FILOSOFIA DA CIÊNCIA E DA TECNOLOGIA
# 35118  POLÍTICAS DE GESTÃO EM CIÊNCIA, TECNOLOGIA E I...
# 35119         FUNDAMENTOS EM DESENVOLVIMENTO SUSTENTÁVEL
# 35120  POLÍTICAS E RECURSOS ENERGÉTICOS PARA O DESENV...
# 35189                  PRÁTICAS DE LEITURA E ESCRITA III
#
#                                      unidade_responsavel
# 192    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 193    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 199    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 200    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 201    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 202    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 216    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 217    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 218    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 219    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 221    DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1222   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1224   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1225   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1226   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1227   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1228   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1229   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1231   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1232   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1234   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1235   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1236   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1238   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1860   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1861   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1873   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 1877   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 2478   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# 2502   DEPARTAMENTO DE ENGENHARIA DE COMPUTACAO E AUT...
# ...                                                  ...
# 35091                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35092                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35093                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35094                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35095                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35096                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35097                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35098                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35099                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35100                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35101                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35102                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35103                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35104                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35105                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35106                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35107                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35108                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35109                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35110                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35111                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35112                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35113                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35114                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35115                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35117                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35118                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35119                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35120                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
# 35189                    ESCOLA DE CIÊNCIAS E TECNOLOGIA
#
# [779 rows x 4 columns]
