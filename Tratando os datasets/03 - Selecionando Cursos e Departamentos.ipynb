# %% [markdown]
# ## Objetivo
#
# Filtrar todos os cursos ativos, de graduação e presenciais que são do campus Natal

# %%
import pandas as pd
import numpy as np

# %%
cursos = pd.read_csv("../data/cursos-de-graduacao.csv",encoding='UTF-8', sep=';')
disciplinas = pd.read_csv("../data/componentes-curriculares-presenciais-ok.csv")

# %%
cursos = cursos.loc[(cursos.modalidade_educacao == 'Presencial') & (cursos.campus == 'Campus Central') & (cursos.situacao_curso == 'ATIVO')]
cursos = cursos[['id_curso','nome','id_unidade_responsavel','unidade_responsavel']]

# %%
cursos
# Out:
#       id_curso                      nome  id_unidade_responsavel  \
# 0      2000002             ADMINISTRAÇÃO                     443
# 3      2000005   ARQUITETURA E URBANISMO                     445
# 4      2000123             ARTES VISUAIS                     442
# 5      2000006           BIBLIOTECONOMIA                     443
# 6      2000122               BIOMEDICINA                     440
# 7      2000013     CIÊNCIA DA COMPUTAÇÃO                     439
# 9      2000009       CIÊNCIAS BIOLÓGICAS                     440
# 10   111635035       CIÊNCIAS BIOLÓGICAS                     440
# 13     2000011        CIÊNCIAS CONTÁBEIS                     443
# 14     2000014       CIÊNCIAS ECONÔMICAS                     443
# 16   111635038          CIÊNCIAS SOCIAIS                     442
# 17     2000015          CIÊNCIAS SOCIAIS                     442
# 18     2000016        COMUNICAÇÃO SOCIAL                     442
# ...
