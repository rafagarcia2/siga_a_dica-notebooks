# %%
import pandas as pd

# %%
matriculas = pd.read_csv("data/matricula-componente-20171.csv", sep=';')

# %%
matriculas.head()
# Out:
#    id_turma                          discente   id_curso  unidade  nota  \
# 0  57597218  880d7ee5080d3b969bf45556f95ac6b4  2000057.0      1.0   8.7
# 1  57597218  880d7ee5080d3b969bf45556f95ac6b4  2000057.0      3.0  10.0
# 2  57597218  880d7ee5080d3b969bf45556f95ac6b4  2000057.0      2.0   8.0
# 3  57597218  07feb1dc40e26ad43ecb18608f102c49  2000057.0      1.0   8.1
# 4  57597218  07feb1dc40e26ad43ecb18608f102c49  2000057.0      3.0  10.0
#
#   reposicao  faltas_unidade  media_final  numero_total_faltas descricao
# 0         f             0.0          8.9                  0.0  APROVADO
# 1         f             0.0          8.9                  0.0  APROVADO
# 2         f             0.0          8.9                  0.0  APROVADO
# 3         f             0.0          9.0                  0.0  APROVADO
# 4         f             0.0          9.0                  0.0  APROVADO

# %%
componentes = pd.read_csv("data/componentes-curriculares-presenciais-ok.csv")

# %%
componentes.head()
# Out:
#    Unnamed: 0  id_componente tipo_componente  codigo nivel  \
# 0           0          18643      DISCIPLINA  MUT508     T
# 1           1          18644      DISCIPLINA  MUT516     T
# 2           2          18645      DISCIPLINA  MUT520     T
# 3           3          18646      DISCIPLINA  MUT165     T
# 4           4          18647      DISCIPLINA  MUT167     T
#
#                                nome unidade_responsavel  ch_teorico  \
# 0  COMPOSIÇÃO EM MÚSICA POPULAR III    ESCOLA DE MÚSICA          60
# 1                      CO-REPETIÇÃO    ESCOLA DE MÚSICA          30
# 2            CONTRABAIXO ACÚSTICO I    ESCOLA DE MÚSICA          30
# 3              PIANO COMPLEMENTAR I    ESCOLA DE MÚSICA          15
# 4            PIANO COMPLEMENTAR III    ESCOLA DE MÚSICA          15
#
#    ch_pratico  ch_estagio       ...         ementa  bibliografia  objetivos  \
# 0           0           0       ...            NaN           NaN        NaN
# ...

# %%
# componentes.nome.str.startswith("INTRO")
componentes_novo = componentes[~componentes.isna()]
# componentes_novo
# componentes_novo[componentes_novo.nome == "INTRODUCAO A FISICA CLASSICA III"]
comp_ect = componentes_novo[(componentes.unidade_responsavel == "ESCOLA DE CIÊNCIAS E TECNOLOGIA")]

# %%
cursos = pd.read_csv("data/cursos-de-graduacao.csv", sep=";")

# %%
cursos[cursos.nome == 'CIÊNCIAS E TECNOLOGIA']
# Out:
#     id_curso                   nome  id_coordenador  \
# 15  10320810  CIÊNCIAS E TECNOLOGIA       5753080.0
#
#                    coordenador situacao_curso nivel_ensino grau_academico  \
# 15  KALINE MELO DE SOUTO VIANA          ATIVO    GRADUAÇÃO    BACHARELADO
#
#    modalidade_educacao           area_conhecimento tipo_oferta     ...      \
# 15          Presencial  Ciências Exatas e da Terra     Regular     ...
#
#    campus id_unidade_responsavel              unidade_responsavel  \
# 15    NaN                   4885  ESCOLA DE CIÊNCIAS E TECNOLOGIA
#
#                        website  data_funcionamento codigo_inep         dou  \
# 15  http://www.prograd.ufrn.br                 NaN    116756.0  2014-03-31
#
#              portaria_reconhecimento  convenio_academico Unnamed: 22
# 15  Portaria nº 217/2014 - DIREG/MEC                 NaN         NaN
#
# [1 rows x 23 columns]

# %%
turma_ifc3 = matriculas[matriculas.id_turma == 57605948]

# %%
notas = turma_ifc3[~turma_ifc3.nota.isna()]

# %%
notas_ifc3 = notas[['id_turma', 'discente', 'media_final', 'reposicao', 'descricao']]

# %%
notas_ifc3 = notas_ifc3.drop_duplicates()

# %%
notas_ifc3.groupby('descricao').count()['discente']
# Out:
# Series([], Name: discente, dtype: int64)

# %%
print("Média da Turma: " + str(notas_ifc3.media_final.mean()))
# Out:
# Média da Turma: nan

# %%
tx_aprov = 100 * (26 + 54) / notas_ifc3.shape[0]

print("Taxa de Aprovação: " + str(tx_aprov) + "%.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-63f00fcae615> in <module>()
# ----> 1 tx_aprov = 100 * (26 + 54) / notas_ifc3.shape[0]
#       2
#       3 print("Taxa de Aprovação: " + str(tx_aprov) + "%.")
#
# ZeroDivisionError: division by zero

# %%
componentes[componentes.id_componente == 57587]
# Out:
#        Unnamed: 0  id_componente tipo_componente   codigo nivel       nome  \
# 22804       22804          57587          MÓDULO  ECT2103     G  CÁLCULO I
#
#                    unidade_responsavel  ch_teorico  ch_pratico  ch_estagio  \
# 22804  ESCOLA DE CIÊNCIAS E TECNOLOGIA          60           0           0
#
#                ...            \
# 22804          ...
#
#                                                   ementa  bibliografia  \
# 22804  Limites e continuidade. Derivada. Aplicações d...           NaN
#
#                                                objetivos  \
# 22804  - Introduzir e capacitar o aluno a entender e ...
#
#                                                 conteudo  \
# 22804  1. Limites1.1 Definição. Limites laterais.1.2 ...
#
#                                 competencias_habilidades  referencias  \
# 22804  Capacitar o aluno a entender e utilizar adequa...          NaN
#
#       ano_programa periodo_programa  modalidade       curso_componente
# ...
