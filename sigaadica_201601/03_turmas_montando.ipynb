# %% [markdown]
# # Montando os dados da Turma
# Nesse notebooks iremos juntas os dados das turmas e tentar montar essa tabela

# %%
import pandas as pd
import numpy as np

# %%
turmas = pd.read_csv('data/turmas-2016.1.csv', sep=';')
turmas.head(100)
# Out:
#     id_turma codigo_turma  id_docente_interno  id_docente_externo  \
# 0   57562257           01                 NaN         109881493.0
# 1   57562261           02           5752206.0                 NaN
# 2   57562261           02                 NaN         109881524.0
# 3   57562265           03           5752206.0                 NaN
# 4   57562265           03                 NaN         110569107.0
# 5   57562269           04             18230.0                 NaN
# 6   57562275           05           5752849.0                 NaN
# 7   57562279           06           5752206.0                 NaN
# 8   57562279           06                 NaN         109881893.0
# 9   57562348           07           5757177.0                 NaN
# 10  57562348           07           5752206.0                 NaN
# 11  57573186           01             23400.0                 NaN
# 12  57573187           01             26652.0                 NaN
# 13  57573188           01             22886.0                 NaN
# 14  57573189           02             22886.0                 NaN
# 15  57573190           03             23400.0                 NaN
# 16  57573191           01             35466.0                 NaN
# 17  57573192           02             35466.0                 NaN
# 18  57573193           03             23400.0                 NaN
# 19  57573194           04             35466.0                 NaN
# 20  57573196           01           5751745.0                 NaN
# 21  57573197           01           5752179.0                 NaN
# 22  57573198           01           5756964.0                 NaN
# 23  57573199           01           5757767.0                 NaN
# 24  57573201           02           5752921.0                 NaN
# 25  57573202           01           5757767.0                 NaN
# 26  57573203           02           5757767.0                 NaN
# 27  57573204           01           5758240.0                 NaN
# 28  57573205           02             17295.0                 NaN
# 29  57573206           03             23477.0                 NaN
# ..       ...          ...                 ...                 ...
# 70  57573250           06             24200.0                 NaN
# 71  57573251           07           3588457.0                 NaN
# 72  57573252           08             21708.0                 NaN
# 73  57573253           09             21708.0                 NaN
# 74  57573254           10           5752936.0                 NaN
# 75  57573255           11             22886.0                 NaN
# 76  57573256           12             63717.0                 NaN
# 77  57573257           13             63717.0                 NaN
# 78  57573258           14           5751745.0                 NaN
# 79  57573259           15           5757134.0                 NaN
# 80  57573260           16             24189.0                 NaN
# 81  57573261           17             24189.0                 NaN
# 82  57573262           18           5757246.0                 NaN
# 83  57573263           19           5758240.0                 NaN
# 84  57573264           20           5758240.0                 NaN
# 85  57573265           21           3031587.0                 NaN
# 86  57573266           22             22876.0                 NaN
# 87  57573267           23           5752202.0                 NaN
# 88  57573268           24           5752202.0                 NaN
# 89  57573269           25           5751599.0                 NaN
# 90  57573270           26           5757639.0                 NaN
# 91  57573271           27           5751559.0                 NaN
# 92  57573272           28           5754083.0                 NaN
# 93  57573273           29           5757838.0                 NaN
# 94  57573274           30           5753085.0                 NaN
# 95  57573275           31           3588457.0                 NaN
# 96  57573276           32           5756964.0                 NaN
# 97  57573277           33             19101.0                 NaN
# 98  57573278           01           5756964.0                 NaN
# 99  57573279           02           3588457.0                 NaN
#
#                         observacao  id_componente_curricular nivel_ensino  \
# 0                              NaN                     56847   LATO SENSU
# 6           NaN       NaN  2016     ...      REGULAR         t
# 7           NaN       NaN  2016     ...      REGULAR         t
# 8           NaN       NaN  2016     ...      REGULAR         t
# 9           NaN       NaN  2016     ...      REGULAR         t
# 10          NaN       NaN  2016     ...      REGULAR         t
# 11          NaN   Sala 21  2016     ...      REGULAR         f
# 12          NaN   Sala 23  2016     ...      REGULAR         f
# 13          NaN   Sala 03  2016     ...      REGULAR         f
# 14          NaN   Sala 03  2016     ...      REGULAR         f
# 15          NaN   Sala 21  2016     ...      REGULAR         f
# 16          NaN    Sala21  2016     ...      REGULAR         f
# 17          NaN   Sala 03  2016     ...      REGULAR         f
# 18          NaN   Sala 21  2016     ...      REGULAR         f
# 19          NaN   Sala 21  2016     ...      REGULAR         f
# 20          NaN   Sala 18  2016     ...      REGULAR         f
# 21          NaN    LAMUCO  2016     ...      REGULAR         f
# 22          NaN   Sala 24  2016     ...      REGULAR         f
# 23          NaN   Sala 23  2016     ...      REGULAR         f
# 24          NaN   Sala 23  2016     ...      REGULAR         f
# 25          NaN   Sala 11  2016     ...      REGULAR         f
# 26          NaN   Sala 23  2016     ...      REGULAR         f
# 27          NaN   Sala 06  2016     ...      REGULAR         f
# 28          NaN   Sala 06  2016     ...      REGULAR         f
# 29          NaN   Sala 05  2016     ...      REGULAR         f
# ..          ...       ...   ...     ...          ...       ...
# 70          NaN   Sala 26  2016     ...      REGULAR         f
# 71          NaN  Sala 'M'  2016     ...      REGULAR         f
# 72          NaN  Sala 'S'  2016     ...      REGULAR         f
# 73          NaN  Sala 'S'  2016     ...      REGULAR         f
# 74          NaN  Sala 'E'  2016     ...      REGULAR         f
# 75          NaN   Sala 04  2016     ...      REGULAR         f
# 76          NaN  Sala 'Q'  2016     ...      REGULAR         f
# 77          NaN  Sala 'Q'  2016     ...      REGULAR         f
# 78          NaN   Sala 18  2016     ...      REGULAR         f
# 79          NaN   Sala 17  2016     ...      REGULAR         f
# 80          NaN  Sala 'S'  2016     ...      REGULAR         f
# 81          NaN  Sala 'S'  2016     ...      REGULAR         f
# 82          NaN  Sala 'N'  2016     ...      REGULAR         f
# 83          NaN   Sala 06  2016     ...      REGULAR         f
# 84          NaN   Sala 06  2016     ...      REGULAR         f
# 85          NaN  Sala 'T'  2016     ...      REGULAR         f
# 86          NaN  Sala 'R'  2016     ...      REGULAR         f
# 87          NaN  Sala 'A'  2016     ...      REGULAR         f
# 88          NaN   Sala 04  2016     ...      REGULAR         f
# 89          NaN  Sala 'P'  2016     ...      REGULAR         f
# 90          NaN   Sala 14  2016     ...      REGULAR         f
# 91          NaN   Sala 15  2016     ...      REGULAR         f
# 92          NaN   Sala 15  2016     ...      REGULAR         f
# 93          NaN   Sala 26  2016     ...      REGULAR         f
# 94          NaN   Sala 12  2016     ...      REGULAR         f
# 95          NaN  Sala 'M'  2016     ...      REGULAR         f
# 93  2016-06-22 16:11:48.327          f                  NaN
# 94  2016-06-08 12:12:59.495          f                  NaN
# 95  2016-06-24 19:58:15.181          f                  NaN
# 96                      NaN          f                  NaN
# 97  2016-06-22 06:47:34.942          f                  NaN
# 98                      NaN          f                  NaN
# 99  2016-06-24 20:01:46.649          f                  NaN
#
#     qtd_aulas_lancadas situacao_turma convenio modalidade_participantes  \
# 0                  0.0    CONSOLIDADA      NaN              A Distância
# 1                  0.0    CONSOLIDADA      NaN              A Distância
# 2                  0.0    CONSOLIDADA      NaN              A Distância
# 3                  0.0    CONSOLIDADA      NaN              A Distância
# 4                  0.0    CONSOLIDADA      NaN              A Distância
# 5                  0.0    CONSOLIDADA      NaN              A Distância
# 6                  0.0    CONSOLIDADA      NaN              A Distância
# 7                  0.0    CONSOLIDADA      NaN              A Distância
# 8                  0.0    CONSOLIDADA      NaN              A Distância
# 9                  0.0    CONSOLIDADA      NaN              A Distância
# 10                 0.0    CONSOLIDADA      NaN              A Distância
# 11                 0.0    CONSOLIDADA      NaN               Presencial
# 12                 NaN       EXCLUÍDA      NaN               Presencial
# 13                54.0    CONSOLIDADA      NaN               Presencial
# 14                54.0    CONSOLIDADA      NaN               Presencial
# 15                 0.0    CONSOLIDADA      NaN               Presencial
# 16                33.0    CONSOLIDADA      NaN               Presencial
# 17                 0.0    CONSOLIDADA      NaN               Presencial
# 18                 0.0    CONSOLIDADA      NaN               Presencial
# 19                 3.0    CONSOLIDADA      NaN               Presencial
# 20                 NaN       EXCLUÍDA      NaN               Presencial
# 21                54.0    CONSOLIDADA      NaN               Presencial
# 22                26.0    CONSOLIDADA      NaN               Presencial
# 23                22.0    CONSOLIDADA      NaN               Presencial
# 24                 NaN       EXCLUÍDA      NaN               Presencial
# 25                26.0    CONSOLIDADA      NaN               Presencial
# 26                22.0    CONSOLIDADA      NaN               Presencial
# 27                51.0    CONSOLIDADA      NaN               Presencial
# 28                 NaN       EXCLUÍDA      NaN               Presencial
# 29                57.0    CONSOLIDADA      NaN               Presencial
# ..                 ...            ...      ...                      ...
# 70                54.0    CONSOLIDADA      NaN               Presencial
# 71                 NaN       EXCLUÍDA      NaN               Presencial
# 72                45.0    CONSOLIDADA      NaN               Presencial
# 73                 NaN       EXCLUÍDA      NaN               Presencial
# 74                48.0    CONSOLIDADA      NaN               Presencial
# 75                51.0    CONSOLIDADA      NaN               Presencial
# 76                51.0    CONSOLIDADA      NaN               Presencial
# 77                57.0    CONSOLIDADA      NaN               Presencial
# 78                54.0    CONSOLIDADA      NaN               Presencial
# 79                57.0    CONSOLIDADA      NaN               Presencial
# 80                54.0    CONSOLIDADA      NaN               Presencial
# 81                57.0    CONSOLIDADA      NaN               Presencial
# 82                 NaN       EXCLUÍDA      NaN               Presencial
# 83                57.0    CONSOLIDADA      NaN               Presencial
# 84                57.0    CONSOLIDADA      NaN               Presencial
# 85                54.0    CONSOLIDADA      NaN               Presencial
# 86                51.0    CONSOLIDADA      NaN               Presencial
# 87                54.0    CONSOLIDADA      NaN               Presencial
# 88                45.0    CONSOLIDADA      NaN               Presencial
# 89                39.0    CONSOLIDADA      NaN               Presencial
# 90                 NaN       EXCLUÍDA      NaN               Presencial
# 91                 NaN       EXCLUÍDA      NaN               Presencial
# 92                57.0    CONSOLIDADA      NaN               Presencial
# 93                57.0    CONSOLIDADA      NaN               Presencial
# 94                45.0    CONSOLIDADA      NaN               Presencial
# 95                57.0    CONSOLIDADA      NaN               Presencial
# 96                 NaN       EXCLUÍDA      NaN               Presencial
# 97                 0.0    CONSOLIDADA      NaN               Presencial
# 98                 NaN       EXCLUÍDA      NaN               Presencial
# 99                57.0    CONSOLIDADA      NaN               Presencial
#
#    Unnamed: 25
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ..         ...
# 70         NaN
# 71         NaN
# 72         NaN
# 73         NaN
# 74         NaN
# 75         NaN
# 76         NaN
# 77         NaN
# 78         NaN
# 79         NaN
# 80         NaN
# 81         NaN
# 82         NaN
# 83         NaN
# 84         NaN
# 85         NaN
# 86         NaN
# 87         NaN
# 88         NaN
# 89         NaN
# 90         NaN
# 91         NaN
# 92         NaN
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
# 98         NaN
# 99         NaN
#
# [100 rows x 26 columns]

# %%
turmas.columns
# Out:
# Index(['id_turma', 'codigo_turma', 'id_docente_interno', 'id_docente_externo',
#        'observacao', 'id_componente_curricular', 'nivel_ensino',
#        'campus_turma', 'local', 'ano', 'periodo', 'data_inicio', 'data_fim',
#        'descricao_horario', 'total_solicitacoes', 'capacidade_aluno', 'tipo',
#        'distancia', 'data_consolidacao', 'agrupadora', 'id_turma_agrupadora',
#        'qtd_aulas_lancadas', 'situacao_turma', 'convenio',
#        'modalidade_participantes', 'Unnamed: 25'],
#       dtype='object')

# %%
# importando disciplinas
disciplinas = pd.read_csv("outputs/displicinas_cet.csv", sep=';')

# %%
turmas_base = turmas[['id_turma', 'id_docente_interno', 'id_componente_curricular']]
turmas_base.shape
# Out:
# (14806, 3)

# %%
disc_base = ['id_componente', 'nome', 'codigo']
disc_ect = disciplinas[disc_base]
disc_ect.shape
# Out:
# (47, 3)

# %%
pd.merge(left=turmas_base, right=disc_ect, left_on='id_componente_curricular', right_on='id_componente', how='inner').shape
# Out:
# (371, 6)

# %%
# Lendo turmas de CeT
matr_cet = pd.read_csv("outputs/turmas_dados_2016_1.csv", sep=";")
matr_cet.shape
# Out:
# (667, 8)

# %%
turma_ax = pd.merge(left=turmas_base, right=matr_cet, how='inner')
turma_ax.head()
# Out:
#    id_turma  id_docente_interno  id_componente_curricular  qnt_disc  \
# 0  57573481           5755040.0                   2051005       112
# 1  57573482           5752289.0                   2051005       129
# 2  57573483           5755040.0                   2051005       124
# 3  57573484           5757919.0                   2051005       114
# 4  57573485           5757919.0                   2051005       103
#
#    qnt_aprovados  qnt_reprovados  qnt_trancamento  media_turma  media_faltas  \
# 0           77.0            32.0              3.0     5.650000      1.375000
# 1           76.0            49.0              4.0     4.831783      0.000000
# 2           78.0            41.0              5.0     5.333871      0.790323
# 3           40.0            65.0              9.0     3.150877      0.000000
# 4           25.0            68.0             10.0     2.543689      0.000000
#
#    qnt_reposicao
# 0            3.0
# 1            3.0
# 2            9.0
# 3           10.0
# 4           10.0

# %%
turmas_com = pd.merge(left=turma_ax, right=disc_ect, left_on='id_componente_curricular', right_on='id_componente', how='inner')
turmas_com[['id_turma', 'nome', 'id_docente_interno', 'qnt_disc']].head()
# Out:
#    id_turma                           nome  id_docente_interno  qnt_disc
# 0  57573481  VETORES E GEOMETRIA ANALÍTICA           5755040.0       112
# 1  57573482  VETORES E GEOMETRIA ANALÍTICA           5752289.0       129
# 2  57573483  VETORES E GEOMETRIA ANALÍTICA           5755040.0       124
# 3  57573484  VETORES E GEOMETRIA ANALÍTICA           5757919.0       114
# 4  57573485  VETORES E GEOMETRIA ANALÍTICA           5757919.0       103

# %%
# importando professores
prof = pd.read_csv("data/docentes.csv", sep=';')
prof.head(2)
# Out:
#    id_servidor   siape                nome        formacao  \
# 0        21041  349938     GILDETE AZEVEDO    DESCONHECIDA
# 1      5753261  709857  MARIA NUBIA PESSOA  ESPECIALIZAÇÃO
#
#             tipo_jornada_trabalho           vinculo  \
# 0  Dedicação exclusiva             Ativo Permanente
# 1  Dedicação exclusiva             Ativo Permanente
#
#                                      categoria  \
# 0     PROFESSOR DE 1  E 2  GRAUS
# 1  PROFESSOR DE ENSINO BASICO DE EX-TERRITORIO
#
#                                     classe_funcional  id_unidade_lotacao  \
# 0  C                                             ...                1452
# 1  D                                             ...                1452
#
#                           lotacao             admissao
# 0  NÚCLEO DE EDUCAÇÃO DA INFÂNCIA  1984-08-27 00:00:00
# 1  NÚCLEO DE EDUCAÇÃO DA INFÂNCIA  2010-01-06 00:00:00

# %%
turma_simp = turmas_com[['id_turma', 'nome', 'id_docente_interno', 'qnt_disc']]
turma_simp['id_docente'] = turma_simp[['id_docente_interno']].applymap(np.int64)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pd.merge(left=turma_simp, right=prof, left_on='id_docente', right_on='')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7166b7596172> in <module>()
# ----> 1 pd.merge(left=turma_simp, right=prof, left_on='id_docente', right_on='')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     549         (self.left_join_keys,
#     550          self.right_join_keys,
# --> 551          self.join_names) = self._get_merge_keys()
#     552
#     553         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     855                             right_keys.append(
#     856                                 right._get_label_or_level_values(
# --> 857                                     rk, stacklevel=stacklevel))
#     858                         else:
#     859                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: ''
