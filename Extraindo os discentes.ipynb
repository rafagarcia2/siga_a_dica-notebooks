# %%
import pandas as pd

# %%
turmas = pd.read_csv("data/turmas-20172.csv", sep=';')

# %%
turmas.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0  57602445           01           5755233.0                 NaN        NaN
# 1  57602445           01                 NaN         120983811.0        NaN
# 2  57602446           01           5757053.0                 NaN        NaN
# 3  57602447           01           5752677.0                 NaN        NaN
# 4  57602447           01           5755233.0                 NaN        NaN
#
#    id_componente_curricular nivel_ensino campus_turma  \
# 0                     63499   LATO SENSU          NaN
# 1                     63499   LATO SENSU          NaN
# 2                     63503   LATO SENSU          NaN
# 3                     63327   LATO SENSU          NaN
# 4                     63327   LATO SENSU          NaN
#
#                                               local   ano     ...      \
# 0          Auditório do DEF e LabLUD do DEF da UFRN  2017     ...
# ...

# %%
docentes = pd.read_csv("data/docentes.csv", sep=';')

# %%
docentes.head()
# Out:
#    id_servidor    siape                            nome        formacao  \
# 0        21041   349938                 GILDETE AZEVEDO    DESCONHECIDA
# 1      5753261   709857              MARIA NUBIA PESSOA  ESPECIALIZAÇÃO
# 2      5752617   713506        RUTILENE SANTOS DE SOUSA        MESTRADO
# 3        22092   709496                ADAUTO CHIAMENTI       DOUTORADO
# 4      2263697  1543339  ADELE GUIMARAES UBARANA SANTOS        MESTRADO
#
#             tipo_jornada_trabalho           vinculo  \
# 0  Dedicação exclusiva             Ativo Permanente
# 1  Dedicação exclusiva             Ativo Permanente
# 2  Dedicação exclusiva             Ativo Permanente
# 3  Dedicação exclusiva             Ativo Permanente
# 4  Dedicação exclusiva             Ativo Permanente
#
#                                           categoria  \
# 0          PROFESSOR DE 1  E 2  GRAUS
# 1       PROFESSOR DE ENSINO BASICO DE EX-TERRITORIO
# 2       PROFESSOR DE ENSINO BASICO DE EX-TERRITORIO
# ...

# %%
docentes.shape
# Out:
# (2393, 11)

# %%
docentes[docentes.id_servidor == 5752477]
# Out:
#       id_servidor    siape                   nome   formacao  \
# 1861      5752477  1475328  NEEMIAS ALVES DE LIMA  DOUTORADO
#
#                tipo_jornada_trabalho           vinculo  \
# 1861  Dedicação exclusiva             Ativo Permanente
#
#                              categoria  \
# 1861  PROFESSOR DO MAGISTERIO SUPERIOR
#
#                                        classe_funcional  id_unidade_lotacao  \
# 1861  Classe C - Adjunto                            ...                4885
#
#                               lotacao             admissao
# 1861  ESCOLA DE CIÊNCIAS E TECNOLOGIA  2009-03-25 00:00:00

# %%
turmas[turmas.id_componente_curricular == 57594]
# turmas
# Out:
#       id_turma codigo_turma  id_docente_interno  id_docente_externo  \
# 5127  57605947           01           5752891.0                 NaN
# 5128  57605948           02           5752477.0                 NaN
# 5129  57605949           03           5752477.0                 NaN
# 5130  57605950           04           5758562.0                 NaN
#
#      observacao  id_componente_curricular nivel_ensino    campus_turma  \
# 5127        NaN                     57594    GRADUAÇÃO  Campus Central
# 5128        NaN                     57594    GRADUAÇÃO  Campus Central
# 5129        NaN                     57594    GRADUAÇÃO  Campus Central
# 5130        NaN                     57594    GRADUAÇÃO  Campus Central
#
#                   local   ano     ...         tipo distancia  \
# 5127       ECT - Sala 5  2017     ...      REGULAR         f
# 5128       ECT - Sala 5  2017     ...      REGULAR         f
# 5129       ECT - Sala 1  2017     ...      REGULAR         f
# ...

# %%
turmas.columns
# Out:
# Index(['id_turma', 'codigo_turma', 'id_docente_interno', 'id_docente_externo',
#        'observacao', 'id_componente_curricular', 'nivel_ensino',
#        'campus_turma', 'local', 'ano', 'periodo', 'data_inicio', 'data_fim',
#        'descricao_horario', 'total_solicitacoes', 'capacidade_aluno', 'tipo',
#        'distancia', 'data_consolidacao', 'agrupadora', 'id_turma_agrupadora',
#        'qtd_aulas_lancadas', 'situacao_turma', 'convenio',
#        'modalidade_participantes', 'Unnamed: 25'],
#       dtype='object')

# %%
avaliacoes = pd.read_csv("avaliacaodocencia.csv", sep=';')

# %%
avaliacoes.columns
# Out:
# Index(['id_docente', 'nome_docente', 'id_turma', 'ano', 'periodo',
#        'qtd_discentes', 'postura_profissional_media',
#        'postura_profissional_DP', 'atuacao_profissional_media',
#        'atuacao_profissional_DP', 'autoavaliacao_aluno_media',
#        'autoavaliacao_aluno_DP'],
#       dtype='object')

# %%
# avaliacoes[avaliacoes.id_docente == 5752477]

# %%
# turmas[turmas.id_turma == 57605667]
turmas[turmas.id_turma == 57605539]
# Out:
#       id_turma codigo_turma  id_docente_interno  id_docente_externo  \
# 4339  57605539           08           5757166.0                 NaN
#
#      observacao  id_componente_curricular nivel_ensino    campus_turma  \
# 4339        NaN                     57587    GRADUAÇÃO  Campus Central
#
#              local   ano     ...         tipo distancia  \
# 4339  ECT - Aud. D  2017     ...      REGULAR         f
#
#             data_consolidacao agrupadora  id_turma_agrupadora  \
# 4339  2017-12-16 13:10:30.852          f                  NaN
#
#       qtd_aulas_lancadas situacao_turma convenio modalidade_participantes  \
# 4339                76.0    CONSOLIDADA      NaN               Presencial
#
#      Unnamed: 25
# 4339         NaN
#
# [1 rows x 26 columns]

# %%
# docentes[docentes.id_servidor == 5757983]
docentes[docentes.id_servidor == 5757166]
# docentes[docentes.id_servidor > 5757000]
# Out:
#       id_servidor    siape                              nome   formacao  \
# 1927      5757166  2998751  PAULO HENRIQUE SOUSA DE OLIVEIRA  DOUTORADO
#
#                tipo_jornada_trabalho           vinculo  \
# 1927  Dedicação exclusiva             Ativo Permanente
#
#                              categoria  \
# 1927  PROFESSOR DO MAGISTERIO SUPERIOR
#
#                                        classe_funcional  id_unidade_lotacao  \
# 1927  Classe C - Adjunto                            ...                4885
#
#                               lotacao             admissao
# 1927  ESCOLA DE CIÊNCIAS E TECNOLOGIA  2015-02-09 00:00:00
